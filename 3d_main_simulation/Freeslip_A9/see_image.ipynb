# %%
from IPython.display import Image
from IPython.display import display
import matplotlib
matplotlib.use('nbagg')
import matplotlib.pyplot as plt
i0 = Image(filename=f'liquid_water/liquidwater_{"%04d" % ( 10 )}.png')
i1 = Image(filename=f'liquid_water/liquidwater_{"%04d" % ( 620 )}.png')
i2 = Image(filename=f'liquid_water/liquidwater_{"%04d" % ( 658 )}.png') 
i3 = Image(filename=f'liquid_water/liquidwater_{"%04d" % ( 707 )}.png') 
i4 = Image(filename=f'liquid_water/liquidwater_{"%04d" % ( 750 )}.png') 
i5 = Image(filename=f'liquid_water/liquidwater_{"%04d" % ( 780 )}.png') 
i6 = Image(filename=f'liquid_water/liquidwater_{"%04d" % ( 825 )}.png') 
i7 = Image(filename=f'liquid_water/liquidwater_{"%04d" % ( 855 )}.png') 
i8 = Image(filename=f'liquid_water/liquidwater_{"%04d" % ( 900 )}.png') 
i9 = Image(filename=f'liquid_water/liquidwater_{"%04d" % ( 950 )}.png') 
i10 = Image(filename=f'liquid_water/liquidwater_{"%04d" % ( 975 )}.png') 
i11 = Image(filename=f'liquid_water/liquidwater_{"%04d" % ( 999 )}.png') 
display(i0, i1, i2, i3, i4, i5, i6, i7, i8, i9, i10, i11)
