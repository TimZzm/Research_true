# %%
# A4_Rstd
from IPython.display import Image
from IPython.display import display
import matplotlib
matplotlib.use('nbagg')
import matplotlib.pyplot as plt
i0 = Image(filename=f'liquid_water/liquidwater_{"%04d" % ( 13 )}.png')
i1 = Image(filename=f'liquid_water/liquidwater_{"%04d" % ( 212 )}.png')
i2 = Image(filename=f'liquid_water/liquidwater_{"%04d" % ( 220 )}.png') 
i3 = Image(filename=f'liquid_water/liquidwater_{"%04d" % ( 413 )}.png') 
i4 = Image(filename=f'liquid_water/liquidwater_{"%04d" % ( 429 )}.png') 
i5 = Image(filename=f'liquid_water/liquidwater_{"%04d" % ( 620 )}.png') 
i6 = Image(filename=f'liquid_water/liquidwater_{"%04d" % ( 637 )}.png') 
i7 = Image(filename=f'liquid_water/liquidwater_{"%04d" % ( 820 )}.png') 
i8 = Image(filename=f'liquid_water/liquidwater_{"%04d" % ( 832 )}.png') 
i9 = Image(filename=f'liquid_water/liquidwater_{"%04d" % ( 1025 )}.png') 
i10 = Image(filename=f'liquid_water/liquidwater_{"%04d" % ( 1230 )}.png') 
i11 = Image(filename=f'liquid_water/liquidwater_{"%04d" % ( 1427 )}.png') 
display(i0, i1, i2, i3, i4, i5, i6, i7, i8, i9, i10, i11)
